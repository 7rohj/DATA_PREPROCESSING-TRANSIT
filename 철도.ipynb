# %% [markdown]
# <a href="https://colab.research.google.com/github/7rohj/.-/blob/main/%EC%B2%A0%EB%8F%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# 구글 드라이브 마운트, 일일이 파일 업로드할 필요 없음
train_info2019 = pd.read_table('/content/drive/MyDrive/철도/2019_TRANSIT_INFO.txt', sep='\t', encoding='euc-kr')
train_path2019 = pd.read_table('/content/drive/MyDrive/철도/2019_TRANSIT_PATH.txt', sep='\t', encoding='euc-kr')
train_info2019.head(3)
# Out:
#    Line_ID  Mode  Type          Name  Peak_Headway  OffPeak_Headway  \
# 0        1     3     1  서울_서울_02(순환)           8.0             10.0
# 1        2     3     1  서울_서울_03(순환)          13.0             17.0
# 2        3     3     1  서울_서울_04(순환)          12.0             17.0
#
#   Avg_Headway  Peak_Frequency  OffPeak_Frequency  Total_Frequency  \
# 0           9            24.0              105.0            129.0
# 1          15             6.0               53.0             59.0
# 2        14.5            13.0               56.0             69.0
#
#   Commercial_Speed  No_seat  Capacity
# 0               30       25        50
# 1               30       25        50
# 2               30       25        50

# %%
train_path2019.head(3)
# Out:
#    Line_ID  Seq  Node_id  Station_Y/N
# 0        1    1   225667            1
# 1        1    2   225665            1
# 2        1    3   221909            0

# %%
print(train_info2019.shape)
print(train_path2019.shape)
# Out:
# (3904, 13)
# (895394, 4)

# %%
# 도로 = 3, 철도 = 4/ 철도만 추출
train_info2019_v2 = train_info2019[train_info2019['Mode'] == 4]
train_info2019_v2 = train_info2019_v2.reset_index(drop=True)
train_info2019_v2.tail(3)
# Out:
#      Line_ID  Mode  Type               Name  Peak_Headway  OffPeak_Headway  \
# 158     6180     4   912  공항철도_서울_인천국제공항_급행          35.0             45.0
# 159     6185     4   209     9호선_종합운동장_보훈병원          11.3             13.2
# 160     6189     4   219        인천2_운연_검단오류           4.8              7.3
#
#     Avg_Headway  Peak_Frequency  OffPeak_Frequency  Total_Frequency  \
# 158       41.54         6.90000          18.700000        25.600000
# 159         999        10.61947          72.727272        83.346742
# 160        4.75        50.00000         115.100000       165.100000
#
#     Commercial_Speed  No_seat  Capacity
# 158             74.7      252       957
# 159            31.07      420      1531
# 160            34.72       68       258

# %% [markdown]
# 이중 for문 돌리면 될듯
# 1차로 윗 정보들을 생성
#
# * ADD는 a
# * LINE은 '6', '8', '9',.. (변동) _ INFO에서의 Line ID
# * MODE은 | (INFO에서의 4번만)
# * VEH는 2
# * HEADWAY는 10, 15, 6.5, 7, 7.5 ... 180 (변동) _ INFO에서의 Peak_Headway
# * SPEED는 0.01
# * DESCR는 노선명 (변동) _INFO에서의 Name
# * UT1, 2, 3은 0으로
#
# 2차로 정보들에 맞는 노선 순서대로 정리
# (0/1 구분)

# %%
alist = []

for i in range(len(train_info2019_v2)):
  alist.append('a')
  alist.append(train_info2019['Line_ID'].tolist()[i])
  alist.append('2')
